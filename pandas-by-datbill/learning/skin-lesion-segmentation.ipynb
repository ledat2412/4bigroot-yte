# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import glob
import PIL
from PIL import Image
import matplotlib.pyplot as plt
import cv2
from keras import backend as K
import os
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, CSVLogger, TensorBoard
# %matplotlib inline

# %%
import re
numbers = re.compile(r'(\d+)')
def numericalSort(value):
  parts = numbers.split(value)
  parts[1::2] = map(int, parts[1::2])
  return parts

# %%
def load_data(split=0.1):  
  images= sorted(glob.glob('../input/ph2dataset/*/trainx/*.bmp'), key=numericalSort)
  masks = sorted(glob.glob('../input/ph2dataset/*/trainy/*.bmp'), key=numericalSort)

  total_size = len(images)
  valid_size = int(split * total_size)
  test_size = int(split * total_size)

  train_x, valid_x = train_test_split(images, test_size=valid_size, random_state=101)
  train_y, valid_y = train_test_split(masks, test_size=valid_size, random_state=101)

  train_x, test_x = train_test_split(train_x, test_size=test_size, random_state=101)
  train_y, test_y = train_test_split(train_y, test_size=test_size, random_state=101)

  return (train_x, train_y), (valid_x, valid_y), (test_x, test_y)

# %%
def read_image(path):
  path = path.decode()
  x = cv2.imread(path, cv2.IMREAD_COLOR)
  x = cv2.resize(x, (256, 256))
  x = x/255.0
  return x

# %%
def read_mask(path):
  path = path.decode()
  x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
  x = cv2.resize(x, (256, 256))
  x = x/255.0
  x = np.expand_dims(x, axis=-1)
  return x

# %%
def tf_parse(x, y):
  def _parse(x, y):
    x = read_image(x)
    y = read_mask(y)
    return x, y
    
  x, y = tf.numpy_function(_parse, [x, y], [tf.float64, tf.float64])
  x.set_shape([256, 256, 3])
  y.set_shape([256, 256, 1])
  return x, y

# %%
def tf_dataset(x, y, batch=8):
  dataset = tf.data.Dataset.from_tensor_slices((x, y))
  dataset = dataset.map(tf_parse)
  dataset = dataset.batch(batch)
  dataset = dataset.repeat()
  return dataset

# %%
(train_x, train_y), (valid_x, valid_y), (test_x, test_y) = load_data()

# %%
def display(arrimg):
  plt.figure(figsize=(20,10))
  for i in range(len(arrimg)):
    plt.subplot(2, 4, i + 1)
    plt.imshow(arrimg[i])
  plt.show()

# %%
def display_mask(arrimg):
  plt.figure(figsize=(20,10))
  for i in range(len(arrimg)):
    plt.subplot(2, 4, i + 1)
    plt.imshow(arrimg[i], cmap='gray')
  plt.show()

# %%
# def iou(y_true, y_pred, smooth = 100):
#   intersection = K.sum(K.abs(y_true * y_pred), axis=-1)
#   sum_i = K.sum(K.square(y_true), axis = -1) + K.sum(K.square(y_pred), axis=-1)
#   iou_val = (intersection + smooth) / (sum_i - intersection + smooth)
#   return iou_val

# %%
def iou(y_true, y_pred):
  def f(y_true, y_pred):
    intersection = (y_true * y_pred).sum()
    union = y_true.sum() + y_pred.sum() - intersection
    x = (intersection + 1e-15) / (union + 1e-15)
    x = x.astype(np.float32)
    return x
  return tf.numpy_function(f, [y_true, y_pred], tf.float32)

# %%
def dice_coeff(y_true, y_pred, smoothness = 100):
  y_true_f = K.flatten(y_true)
  y_pred_f = K.flatten(y_pred)
  intersection = K.sum(y_true_f * y_pred_f)
  return (2. * intersection + smoothness) / (K.sum(y_true_f) + K.sum(y_pred_f) + smoothness)

# %%
def precision(y_true, y_pred):    
  true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
  predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
  precision = true_positives / (predicted_positives + K.epsilon())
  return precision

# %%
def recall(y_true, y_pred):    
  true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
  possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
  recall = true_positives / (possible_positives + K.epsilon())
  return recall

# %%
def accuracy(y_true, y_pred):    
  return K.mean(K.equal(y_true, K.round(y_pred)))

# %%
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

# %%
def double_conv(x, num_filters):
  x = Conv2D(num_filters, (3, 3), padding='same')(x)
  x = BatchNormalization()(x)
  x = Activation('relu')(x)

  x = Conv2D(num_filters, (3, 3), padding='same')(x)
  x = BatchNormalization()(x)
  x = Activation('relu')(x)
  
  return x

# %%
def double_conv_transpose(x, num_filters):
  x = Conv2DTranspose(num_filters, (3, 3), padding='same')(x)
  x = BatchNormalization()(x)
  x = Activation('relu')(x)

  x = Conv2DTranspose(num_filters, (3, 3), padding='same')(x)
  x = BatchNormalization()(x)
  x = Activation('relu')(x)

  return x

# %%
def UNET():
  size = 256
  num_filters = [64, 128, 256, 512, 1024]
  inputs = Input((size, size, 3))

  skip_x = []
  x = inputs

  for f in num_filters:
      x = double_conv(x, f)
      skip_x.append(x)
      x = MaxPool2D((2, 2))(x)

  x = double_conv(x, num_filters[-1])

  num_filters.reverse()
  skip_x.reverse()

  for i, f in enumerate(num_filters):
      x = UpSampling2D((2, 2))(x)
      xs = skip_x[i]
      x = Concatenate()([x, xs])
      x = double_conv(x, f)

  x = Conv2D(1, (1, 1), padding="same")(x)
  x = Activation("sigmoid")(x)

  return Model(inputs, x)

# %%
model = UNET()
model.compile(optimizer= Adam(learning_rate=1e-4), loss= ["binary_crossentropy"]
                  , metrics=[iou, dice_coeff, precision, recall, accuracy])
model.summary()
# Out:
# 2021-11-18 06:10:18.139465: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-18 06:10:18.265385: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-18 06:10:18.266165: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-18 06:10:18.267396: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-11-18 06:10:18.273975: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-18 06:10:18.274725: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-18 06:10:18.275422: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-18 06:10:20.036460: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-18 06:10:20.037310: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-18 06:10:20.038033: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-18 06:10:20.038615: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 256, 256, 64) 1792        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 256, 256, 64) 256         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 256, 256, 64) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 64) 36928       activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 256, 256, 64) 256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 256, 256, 64) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 128, 128, 64) 0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 128, 128, 128 73856       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 128, 128, 128 512         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 128, 128, 128 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 128, 128 147584      activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 128, 128, 128 512         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 128, 128, 128 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 128)  0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 256)  295168      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 64, 64, 256)  1024        conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 64, 64, 256)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 64, 256)  590080      activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 64, 64, 256)  1024        conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 64, 64, 256)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 256)  0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 512)  1180160     max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 32, 512)  2048        conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 32, 32, 512)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 512)  2359808     activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 32, 32, 512)  2048        conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 32, 32, 512)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 512)  0           activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 1024) 4719616     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16, 16, 1024) 4096        conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 16, 16, 1024) 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 1024) 9438208     activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 16, 16, 1024) 4096        conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 16, 16, 1024) 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 8, 8, 1024)   0           activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 8, 8, 1024)   9438208     max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 8, 8, 1024)   4096        conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 8, 8, 1024)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 8, 8, 1024)   9438208     activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 8, 8, 1024)   4096        conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 8, 8, 1024)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 16, 16, 1024) 0           activation_11[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 16, 16, 2048) 0           up_sampling2d[0][0]
#                                                                  activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 1024) 18875392    concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 16, 16, 1024) 4096        conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 16, 16, 1024) 0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 16, 1024) 9438208     activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 16, 16, 1024) 4096        conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 16, 16, 1024) 0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 32, 32, 1024) 0           activation_13[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32, 32, 1536) 0           up_sampling2d_1[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 32, 32, 512)  7078400     concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 32, 32, 512)  2048        conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 32, 32, 512)  0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 32, 32, 512)  2359808     activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 32, 32, 512)  2048        conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 32, 32, 512)  0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 64, 64, 512)  0           activation_15[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 64, 64, 768)  0           up_sampling2d_2[0][0]
#                                                                  activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 64, 64, 256)  1769728     concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 64, 64, 256)  1024        conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 64, 64, 256)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 64, 64, 256)  590080      activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 64, 64, 256)  1024        conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 64, 64, 256)  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 128, 128, 256 0           activation_17[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 128, 128, 384 0           up_sampling2d_3[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 128, 128, 128 442496      concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 128, 128, 128 512         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 128, 128, 128 0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 128, 128, 128 147584      activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 128, 128, 128 512         conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 128, 128, 128 0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 256, 256, 128 0           activation_19[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 256, 256, 192 0           up_sampling2d_4[0][0]
#                                                                  activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 256, 256, 64) 110656      concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 256, 256, 64) 256         conv2d_20[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 256, 256, 64) 0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 256, 256, 64) 36928       activation_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 256, 256, 64) 256         conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 256, 256, 64) 0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 256, 256, 1)  65          activation_21[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 256, 256, 1)  0           conv2d_22[0][0]
# ==================================================================================================
# Total params: 78,608,897
# Trainable params: 78,588,929
# Non-trainable params: 19,968
# __________________________________________________________________________________________________

# %%
batch = 8
epochs = 50
train_dataset = tf_dataset(train_x, train_y, batch=batch)
valid_dataset = tf_dataset(valid_x, valid_y, batch=batch)

# %%
train_steps = len(train_x)//batch
valid_steps = len(valid_x)//batch

if len(train_x) % batch != 0:
    train_steps += 1
if len(valid_x) % batch != 0:
    valid_steps += 1

# %%
history = model.fit(train_dataset,
        validation_data=valid_dataset,        
        epochs=epochs,
        steps_per_epoch=train_steps,
        validation_steps=valid_steps      
        )
# Out:
# 2021-11-18 06:10:21.133937: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/50
# 2021-11-18 06:10:25.011741: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 20/20 [==============================] - 19s 400ms/step - loss: 0.4755 - iou: 0.4565 - dice_coeff: 0.6210 - precision: 0.6928 - recall: 0.8492 - accuracy: 0.7869 - val_loss: 0.6578 - val_iou: 0.1981 - val_dice_coeff: 0.3287 - val_precision: 0.0279 - val_recall: 0.0011 - val_accuracy: 0.7387
# Epoch 2/50
# 20/20 [==============================] - 6s 323ms/step - loss: 0.2737 - iou: 0.5803 - dice_coeff: 0.7301 - precision: 0.8565 - recall: 0.8496 - accuracy: 0.9000 - val_loss: 0.5858 - val_iou: 0.1942 - val_dice_coeff: 0.3237 - val_precision: 0.0079 - val_recall: 3.1556e-05 - val_accuracy: 0.7488
# Epoch 3/50
# 20/20 [==============================] - 6s 323ms/step - loss: 0.2412 - iou: 0.6133 - dice_coeff: 0.7576 - precision: 0.8766 - recall: 0.8659 - accuracy: 0.9122 - val_loss: 0.5269 - val_iou: 0.2271 - val_dice_coeff: 0.3684 - val_precision: 0.9517 - val_recall: 0.5911 - val_accuracy: 0.8864
# Epoch 4/50
# 20/20 [==============================] - 7s 324ms/step - loss: 0.2177 - iou: 0.6414 - dice_coeff: 0.7786 - precision: 0.8803 - recall: 0.8793 - accuracy: 0.9192 - val_loss: 0.4945 - val_iou: 0.2311 - val_dice_coeff: 0.3740 - val_precision: 0.9533 - val_recall: 0.5067 - val_accuracy: 0.8682
# Epoch 5/50
# 20/20 [==============================] - 6s 322ms/step - loss: 0.
50
# 20/20 [==============================] - 6s 322ms/step - loss: 0.0602 - iou: 0.8656 - dice_coeff: 0.9268 - precision: 0.9729 - recall: 0.9691 - accuracy: 0.9807 - val_loss: 0.1437 - val_iou: 0.7541 - val_dice_coeff: 0.8592 - val_precision: 0.8801 - val_recall: 0.9320 - val_accuracy: 0.9475
# Epoch 35/50
# 20/20 [==============================] - 7s 325ms/step - loss: 0.0545 - iou: 0.8719 - dice_coeff: 0.9305 - precision: 0.9731 - recall: 0.9740 - accuracy: 0.9827 - val_loss: 0.1245 - val_iou: 0.7636 - val_dice_coeff: 0.8655 - val_precision: 0.9236 - val_recall: 0.9060 - val_accuracy: 0.9563
# Epoch 36/50
# 20/20 [==============================] - 7s 324ms/step - loss: 0.0490 - iou: 0.8805 - dice_coeff: 0.9352 - precision: 0.9759 - recall: 0.9770 - accuracy: 0.9848 - val_loss: 0.1307 - val_iou: 0.7621 - val_dice_coeff: 0.8649 - val_precision: 0.9295 - val_recall: 0.8917 - val_accuracy: 0.9537
# Epoch 37/50
# 20/20 [==============================] - 6s 321ms/step - loss: 0.0492 - iou: 0.8818 - dice_coeff: 0.9361 - precision: 0.9762 - recall: 0.9756 - accuracy: 0.9843 - val_loss: 0.1255 - val_iou: 0.7651 - val_dice_coeff: 0.8668 - val_precision: 0.9241 - val_recall: 0.9012 - val_accuracy: 0.9545
# Epoch 38/50
# 20/20 [==============================] - 6s 323ms/step - loss: 0.0461 - iou: 0.8863 - dice_coeff: 0.9387 - precision: 0.9769 - recall: 0.9786 - accuracy: 0.9855 - val_loss: 0.1365 - val_iou: 0.7529 - val_dice_coeff: 0.8590 - val_precision: 0.9333 - val_recall: 0.8819 - val_accuracy: 0.9520
# Epoch 39/50
# 20/20 [==============================] - 6s 322ms/step - loss: 0.0546 - iou: 0.8802 - dice_coeff: 0.9353 - precision: 0.9756 - recall: 0.9727 - accuracy: 0.9827 - val_loss: 0.1583 - val_iou: 0.7280 - val_dice_coeff: 0.8424 - val_precision: 0.9180 - val_recall: 0.8564 - val_accuracy: 0.9449
# Epoch 40/50
# 20/20 [==============================] - 6s 322ms/step - loss: 0.1413 - iou: 0.7864 - dice_coeff: 0.8769 - precision: 0.9314 - recall: 0.9174 - accuracy: 0.9492 - val_loss: 0.9345 - val_iou: 0.5880 - val_dice_coeff: 0.7394 - val_precision: 0.6799 - val_recall: 0.8590 - val_accuracy: 0.8644
# Epoch 41/50
# 20/20 [==============================] - 7s 327ms/step - loss: 0.1788 - iou: 0.7086 - dice_coeff: 0.8271 - precision: 0.8850 - recall: 0.8995 - accuracy: 0.9295 - val_loss: 8.4492 - val_iou: 0.3489 - val_dice_coeff: 0.5145 - val_precision: 0.3571 - val_recall: 0.9755 - val_accuracy: 0.5674
# Epoch 42/50
# 20/20 [==============================] - 6s 322ms/step - loss: 0.1249 - iou: 0.7785 - dice_coeff: 0.8740 - precision: 0.9231 - recall: 0.9366 - accuracy: 0.9534 - val_loss: 0.4192 - val_iou: 0.6328 - val_dice_coeff: 0.7740 - val_precision: 0.7695 - val_recall: 0.8230 - val_accuracy: 0.8971
# Epoch 43/50
# 20/20 [==============================] - 6s 322ms/step - loss: 0.0937 - iou: 0.8172 - dice_coeff: 0.8979 - precision: 0.9401 - recall: 0.9521 - accuracy: 0.9653 - val_loss: 0.3466 - val_iou: 0.6550 - val_dice_coeff: 0.7906 - val_precision: 0.7842 - val_recall: 0.8587 - val_accuracy: 0.9074
# Epoch 44/50
# 20/20 [==============================] - 6s 322ms/step - loss: 0.0806 - iou: 0.8378 - dice_coeff: 0.9109 - precision: 0.9584 - recall: 0.9567 - accuracy: 0.9715 - val_loss: 0.1657 - val_iou: 0.7258 - val_dice_coeff: 0.8408 - val_precision: 0.9168 - val_recall: 0.8339 - val_accuracy: 0.9387
# Epoch 45/50
# 20/20 [==============================] - 6s 324ms/step - loss: 0.0657 - iou: 0.8577 - dice_coeff: 0.9226 - precision: 0.9630 - recall: 0.9679 - accuracy: 0.9770 - val_loss: 0.1292 - val_iou: 0.7558 - val_dice_coeff: 0.8606 - val_precision: 0.9375 - val_recall: 0.8723 - val_accuracy: 0.9542
# Epoch 46/50
# 20/20 [==============================] - 6s 323ms/step - loss: 0.0618 - iou: 0.8666 - dice_coeff: 0.9277 - precision: 0.9680 - recall: 0.9676 - accuracy: 0.9786 - val_loss: 0.1134 - val_iou: 0.7741 - val_dice_coeff: 0.8721 - val_precision: 0.9383 - val_recall: 0.8974 - val_accuracy: 0.9603
# Epoch 47/50
# 20/20 [==============================] - 6s 322ms/step - loss: 0.0616 - iou: 0.8675 - dice_coeff: 0.9282 - precision: 0.9653 - recall: 0.9701 - accuracy: 0.9785 - val_loss: 0.1240 - val_iou: 0.7672 - val_dice_coeff: 0.8681 - val_precision: 0.9531 - val_recall: 0.8576 - val_accuracy: 0.9535
# Epoch 48/50
# 20/20 [==============================] - 6s 322ms/step - loss: 0.0574 - iou: 0.8712 - dice_coeff: 0.9300 - precision: 0.9691 - recall: 0.9666 - accuracy: 0.9797 - val_loss: 0.1130 - val_iou: 0.7768 - val_dice_coeff: 0.8741 - val_precision: 0.9438 - val_recall: 0.8973 - val_accuracy: 0.9608
# Epoch 49/50
# 20/20 [==============================] - 6s 322ms/step - loss: 0.0555 - iou: 0.8748 - dice_coeff: 0.9324 - precision: 0.9688 - recall: 0.9722 - accuracy: 0.9805 - val_loss: 0.1393 - val_iou: 0.7572 - val_dice_coeff: 0.8615 - val_precision: 0.9120 - val_recall: 0.8916 - val_accuracy: 0.9508
# Epoch 50/50
# 20/20 [==============================] - 6s 323ms/step - loss: 0.0505 - iou: 0.8841 - dice_coeff: 0.9377 - precision: 0.9731 - recall: 0.9733 - accuracy: 0.9824 - val_loss: 0.1456 - val_iou: 0.7464 - val_dice_coeff: 0.8544 - val_precision: 0.9021 - val_recall: 0.8918 - val_accuracy: 0.9475

# %%
from tensorflow.keras.utils import plot_model
plot_model(model)

# %%
def mask_parse(mask):
  mask = np.squeeze(mask)
  mask = [mask, mask, mask]
  mask = np.transpose(mask, (1, 2, 0))
  return mask

# %%
def read_image(path):
  x = cv2.imread(path, cv2.IMREAD_COLOR)
  x = cv2.resize(x, (256, 256))
  x = x/255.0
  return x

def read_mask(path):
  x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
  x = cv2.resize(x, (256, 256))
  x = np.expand_dims(x, axis=-1)
  return x

# %%
def display_new(no=0):
  x=test_x[no]
  y=test_y[no]
  plt.figure(figsize=(15, 15))
  plt.subplot(1, 3, 1)
  plt.title('Input Image')
  x_r = read_image(x)
  plt.imshow(x_r)
  plt.axis('off')
  plt.subplot(1, 3, 2)
  plt.title('Ground Truth')
  y_r = read_image(y)
  plt.imshow(y_r)
  plt.axis('off')
  plt.subplot(1, 3, 3)
  plt.title('Predicted Image')
  x=read_image(x)
  y=read_mask(y)
  y_pred = model.predict(np.expand_dims(x, axis=0))[0] > 0.5
  y_pred = mask_parse(y_pred) * 255.0
  y_pred = cv2.resize(y_pred, (256, 256))
  plt.imshow(y_pred, cmap='gray')
  plt.axis('off')
  plt.show()

# %%
display_new(5)

# %%
display_new(1)

# %%
display_new(2)

# %%
display_new(17)
