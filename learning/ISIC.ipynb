# %%
import pandas as pd

# %%
test = pd.read_csv("ISIC_2020_Dataset/ISIC_2020_Train_Metadata.csv")
pd.options.display.max_rows = 9999
test.sample(frac=0.1)
# Out:
#          image_name  patient_id   lesion_id     sex  age_approx  \
# 26357  ISIC_7997132  IP_0085748  IL_5325444  female        45.0
# 4029   ISIC_1318137  IP_5867829  IL_0445511    male        65.0
# 11507  ISIC_3549225  IP_2008749  IL_1400326    male        40.0
# 11914  ISIC_3671424  IP_0962375  IL_8946737  female        55.0
# 20927  ISIC_6354541  IP_1244021  IL_3251786  female        35.0
# 21188  ISIC_6432672  IP_1153670  IL_6019719    male        45.0
# 12858  ISIC_3957077  IP_8191902  IL_0984826    male        60.0
# 28803  ISIC_8710935  IP_8152038  IL_3153531    male        55.0
# 6112   ISIC_1929037  IP_7770500  IL_0866261    male        60.0
# 16541  ISIC_5061168  IP_9826072  IL_7332685    male        70.0
# 29562  ISIC_8940603  IP_6332843  IL_6016762    male        40.0
# 3574   ISIC_1178227  IP_6901441  IL_9252521  female        35.0
# 9713   ISIC_3008399  IP_1153670  IL_8047158    male        45.0
# 11030  ISIC_3402149  IP_4959878  IL_2628388  female        30.0
# ...

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33126 entries, 0 to 33125
# Data columns (total 9 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   image_name                     33126 non-null  object
#  1   patient_id                     33126 non-null  object
#  2   lesion_id                      33126 non-null  object
#  3   sex                            33061 non-null  object
#  4   age_approx                     33058 non-null  float64
#  5   anatom_site_general_challenge  32599 non-null  object
#  6   diagnosis                      33126 non-null  object
#  7   benign_malignant               33126 non-null  object
#  8   target                         33126 non-null  int64
# dtypes: float64(1), int64(1), object(7)
# memory usage: 2.3+ MB

# %%
test['diagnosis'].value_counts()
# Out:
# diagnosis
# unknown                               27124
# nevus                                  5193
# melanoma                                584
# seborrheic keratosis                    135
# lentigo NOS                              44
# lichenoid keratosis                      37
# solar lentigo                             7
# cafe-au-lait macule                       1
# atypical melanocytic proliferation        1
# Name: count, dtype: int64
